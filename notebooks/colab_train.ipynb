# %% [markdown]
# # Skip-GANomaly++ Colab Notebook
# Train the baseline, the UNet++ variant, and the ensemble.

# %%
# !pip install -q torch torchvision umap-learn pandas matplotlib scikit-learn pillow tqdm

# %%
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')
ROOT = Path('/content/drive/MyDrive/skipganomaly_data')

# %%
# !git clone https://github.com/YOUR_FORK/skip-ganomaly.git
# %cd skip-ganomaly

# %%
# Example: train single model
# !python -m src.train_single --data-root $ROOT --out-dir /content/drive/MyDrive/runs/skip --epochs 1 --batch-size 8 --device cuda

# %%
# Example: train ensemble
# !python -m src.train_ensemble --data-root $ROOT --out-dir /content/drive/MyDrive/runs/ensemble --epochs 1 --batch-size 8 --device cuda --ensemble-init pretrained --skip-ckpt /content/drive/MyDrive/runs/skip/best.pt --pp-ckpt /content/drive/MyDrive/runs/pp/best.pt
